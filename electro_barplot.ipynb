# %%
import pandas as pd

# %%
df = pd.read_excel('남북한발전전력량.xlsx')

# %%
df
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  ...  2011  2012  2013  2014  2015  2016
# 0        남한     합계  1077  1186  1310  1444  ...  4969  5096  5171  5220  5281  5404
# 1       NaN     수력    64    51    49    60  ...    78    77    84    78    58    66
# 2       NaN     화력   484   573   696   803  ...  3343  3430  3581  3427  3402  3523
# 3       NaN    원자력   529   563   565   581  ...  1547  1503  1388  1564  1648  1620
# 4       NaN    신재생     -     -     -     -  ...     -    86   118   151   173   195
# 5        북한     합계   277   263   247   221  ...   211   215   221   216   190   239
# 6       NaN     수력   156   150   142   133  ...   132   135   139   130   100   128
# 7       NaN     화력   121   113   105    88  ...    79    80    82    86    90   111
# 8       NaN    원자력     -     -     -     -  ...     -     -     -     -     -     -
#
# [9 rows x 29 columns]

# %% [markdown]
# iloc[숫자] 행 가져오기

# %%
df.iloc[0:5,0:2]
# Out:
#   전력량 (억㎾h) 발전 전력별
# 0        남한     합계
# 1       NaN     수력
# 2       NaN     화력
# 3       NaN    원자력
# 4       NaN    신재생

# %% [markdown]
# iloc 일부 행 가져오기

# %%
df.iloc[[0,5],2:]
# Out:
#    1990  1991  1992  1993  1994  1995  ...  2011  2012  2013  2014  2015  2016
# 0  1077  1186  1310  1444  1650  1847  ...  4969  5096  5171  5220  5281  5404
# 5   277   263   247   221   231   230  ...   211   215   221   216   190   239
#
# [2 rows x 27 columns]

# %% [markdown]
# loc('문자') 행 가져오기

# %%
df.loc['0':'2','1990':'2000']
# Out:
#    1990  1991  1992  1993  1994  1995  1996  1997  1998  1999  2000
# 0  1077  1186  1310  1444  1650  1847  2055  2244  2153  2393  2664
# 1    64    51    49    60    41    55    52    54    61    61    56
# 2   484   573   696   803  1022  1122  1264  1420  1195  1302  1518

# %% [markdown]
# loc 일부 행만 가져오기

# %%
df.loc[[0,5],:]
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  ...  2011  2012  2013  2014  2015  2016
# 0        남한     합계  1077  1186  1310  1444  ...  4969  5096  5171  5220  5281  5404
# 5        북한     합계   277   263   247   221  ...   211   215   221   216   190   239
#
# [2 rows x 29 columns]

# %%
df_ns = df.iloc[[0,5,],2:]

# %%
# df.columns = [, , , , ,]
df_ns.index = ['South','North']
df_ns
# Out:
#        1990  1991  1992  1993  1994  1995  ...  2011  2012  2013  2014  2015  2016
# South  1077  1186  1310  1444  1650  1847  ...  4969  5096  5171  5220  5281  5404
# North   277   263   247   221   231   230  ...   211   215   221   216   190   239
#
# [2 rows x 27 columns]

# %%
df_ns = df_ns.transpose()
df_ns
# Out:
#      South North
# 1990  1077   277
# 1991  1186   263
# 1992  1310   247
# 1993  1444   221
# 1994  1650   231
# 1995  1847   230
# 1996  2055   213
# 1997  2244   193
# 1998  2153   170
# 1999  2393   186
# 2000  2664   194
# 2001  2852   202
# 2002  3065   190
# 2003  3225   196
# 2004  3421   206
# 2005  3646   215
# 2006  3812   225
# 2007  4031   236
# 2008  4224   255
# 2009  4336   235
# 2010  4747   237
# 2011  4969   211
# 2012  5096   215
# 2013  5171   221
# 2014  5220   216
# 2015  5281   190
# 2016  5404   239

# %%
df_ns.plot(kind='bar')

# %%
type(df_ns)
